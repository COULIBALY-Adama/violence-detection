# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.0'

# %%
# nous confirmerons que nous pouvons nous connecter au GPU avec tensorflow:
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# %cd /content/drive/My Drive/Violence_Detection/ViolenceDetection01
# %ls
# Out:
# /content/drive/My Drive/Violence_Detection/ViolenceDetection01
# data/        settings/  Train01.ipynb              val.txt
# Deploy3.py   src/       Train1.py                  Violence01.ipynb
# Deploy.py    temp/      Train.py
# Evaluate.py  test.txt   train.txt
# README.md    tools/     Train_Val_Test_spliter.py

# %%
# !pip install sk-video
# !apt install ffmpeg
# Out:
# ...
#      |████████████████████████████████| 2.3MB 4.8MB/s
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
import cv2
import skvideo.io
#%cd /content/drive/My Drive/Violence_Detection/ViolenceDetection01
#%cd /content/drive/My Drive/Violence_Detection/ViolenceDetection01/temp/model
# %cd /content/drive/My Drive/Violence_Detection/ViolenceDetection01/settings/
# %ls
# Out:
# /content/drive/My Drive/Violence_Detection/ViolenceDetection01/settings
# DataSettings.py    EvaluationSettings.py  LayerSettings.py  __pycache__/
# DeploySettings.py  __init__.py            NetSettings.py    TrainSettings.py

# %%
# %cd /content/drive/My Drive/Violence_Detection/violenceDetection1Fc

# !python Train_Val_Test_spliter.py
# Out:
# /content/drive/My Drive/Violence_Detection/violenceDetection1Fc

# %%
# %cd /content/drive/My Drive/Violence_Detection/ViolenceDetection01

# !python Train.py
# Out:
# /content/drive/My Drive/Violence_Detection/ViolenceDetection01
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/drive/My Drive/Violence_Detection/ViolenceDetection01/src/Classifier.py:8: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
#
#  Using Network:  src.net.G2D19_P2OF_ResHB_1LSTM
#
# WARNING:tensorflow:From /content/drive/My Drive/Violence_Detection/ViolenceDetection01/src/net/G2D19_P2OF_ResHB_1LSTM.py:33: The name tf.GraphDef is deprecated. Please use tf.compat.v1.GraphDef instead.
#
# ...
